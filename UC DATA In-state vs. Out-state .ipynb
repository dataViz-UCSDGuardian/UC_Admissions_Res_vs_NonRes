# %%
import matplotlib.pyplot as plt

# %%
years = []
resAd = []
resAp = []
nonResAd = []
nonResAp = []
apRatio = []
adRatio = []

UCBresAd = []
UCBresAp = []
UCBnonResAd = []
UCBnonResAp = []
UCBapRatio = []
UCBadRatio = []

UCDresAd = []
UCDresAp = []
UCDnonResAd = []
UCDnonResAp = []
UCDapRatio = []
UCDadRatio = []

UCLAresAd = []
UCLAresAp = []
UCLAnonResAd = []
UCLAnonResAp = []
UCLAapRatio = []
UCLAadRatio = []

UCMresAd = []
UCMresAp = []
UCMnonResAd = []
UCMnonResAp = []
UCMapRatio = []
UCMadRatio = []

UCIresAd = []
UCIresAp = []
UCInonResAd = []
UCInonResAp = []
UCIapRatio = []
UCIadRatio = []

UCRresAd = []
UCRresAp = []
UCRnonResAd = []
UCRnonResAp = []
UCRapRatio = []
UCRadRatio = []

UCSBresAd = []
UCSBresAp = []
UCSBnonResAd = []
UCSBnonResAp = []
UCSBapRatio = []
UCSBadRatio = []

UCSCresAd = []
UCSCresAp = []
UCSCnonResAd = []
UCSCnonResAp = []
UCSCapRatio = []
UCSCadRatio = []

# %%
resAd = [ 13973, 15514,  16566,  15820, 16182]
resAp = [ 45615, 48300,  50632 , 52127, 53665]

nonResAd = [ 2217+2022, 3822+3603, 3894+4232, 3688+5077, 4516+5797]
nonResAp = [ 4024+3822, 5778+6760 ,6822+9946, 8534+12794, 9731+14695]
#UCyears = [2011, 2012, 2013, 2014, 2015]
UCyears = [1, 2, 3, 4, 5]
years = [2012, 2013, 2014]

diff = []
floatD = 0.0
apRatio = [ 25.96, 33.13, 40.85, 45.52]
adRatio = [ 47.85, 49.60, 55.61, 63.73]
for i in range(0, len(apRatio)):
    apRatio[i] = 1/apRatio[i] * 100
    adRatio[i] = 1/adRatio[i] * 100
    diff.append(apRatio[i] - adRatio[i])
yearsRatio = [2, 3, 4, 5]

resAdG = [16182, 16932]
resApG = [53665, 53665]
nonResAdG = [10313, 10313]
nonResApG = [24426, 24426]

apRatioG = [45.52, 45.52]
adRatioG = [63.74, 60.91 ]
diffG = []
for i in range(0, len(apRatioG)):
    apRatioG[i] = 1/apRatioG[i] * 100
    adRatioG[i] = 1/adRatioG[i] * 100
    diffG.append(apRatioG[i] - adRatioG[i])
yearsG = [5, 6]

tableau = [(31, 119, 4180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

for i in range(len(tableau)):    
    r, g, b = tableau[i]    
    tableau[i] = (r / 255., g / 255., b / 255.)

# %%
import openpyxl

wb = openpyxl.load_workbook('admissions.xlsx')
sheet1 = wb.get_sheet_by_name("Sheet1")
for i in range(2,5):
    UCBresAd.append(sheet1.cell(row=3, column = i).value)
    UCBresAp.append(sheet1.cell(row=4, column = i).value)
    UCBnonResAd.append(sheet1.cell(row=5, column = i).value)
    UCBnonResAp.append(sheet1.cell(row=6, column = i).value)
    UCBapRatio.append(sheet1.cell(row=7, column = i).value)
    UCBadRatio.append(sheet1.cell(row=8, column = i).value)

    UCDresAd.append(sheet1.cell(row=10, column = i).value)
    UCDresAp.append(sheet1.cell(row=11, column = i).value)
    UCDnonResAd.append(sheet1.cell(row=12, column = i).value)
    UCDnonResAp.append(sheet1.cell(row=13, column = i).value)
    UCDapRatio.append(sheet1.cell(row=14, column = i).value)
    UCDadRatio.append(sheet1.cell(row=15, column = i).value)
    
    UCLAresAd.append(sheet1.cell(row=17, column = i).value)
    UCLAresAp.append(sheet1.cell(row=18, column = i).value)
    UCLAnonResAd.append(sheet1.cell(row=19, column = i).value)
    UCLAnonResAp.append(sheet1.cell(row=20, column = i).value)
    UCLAapRatio.append(sheet1.cell(row=21, column = i).value)
    UCLAadRatio.append(sheet1.cell(row=22, column = i).value)

    UCMresAd.append(sheet1.cell(row=24, column = i).value)
    UCMresAp.append(sheet1.cell(row=25, column = i).value)
    UCMnonResAd.append(sheet1.cell(row=26, column = i).value)
    UCMnonResAp.append(sheet1.cell(row=27, column = i).value)
    UCMapRatio.append(sheet1.cell(row=28, column = i).value)
    UCMadRatio.append(sheet1.cell(row=29, column = i).value)

    UCIresAd.append(sheet1.cell(row=31, column = i).value)
    UCIresAp.append(sheet1.cell(row=32, column = i).value)
    UCInonResAd.append(sheet1.cell(row=33, column = i).value)
    UCInonResAp.append(sheet1.cell(row=34, column = i).value)
    UCIapRatio.append(sheet1.cell(row=35, column = i).value)
    UCIadRatio.append(sheet1.cell(row=36, column = i).value)

    UCRresAd.append(sheet1.cell(row=38, column = i).value)
    UCRresAp.append(sheet1.cell(row=39, column = i).value)
    UCRnonResAd.append(sheet1.cell(row=40, column = i).value)
    UCRnonResAp.append(sheet1.cell(row=41, column = i).value)
    UCRapRatio.append(sheet1.cell(row=42, column = i).value)
    UCRadRatio.append(sheet1.cell(row=43, column = i).value)

    UCSBresAd.append(sheet1.cell(row=45, column = i).value)
    UCSBresAp.append(sheet1.cell(row=46, column = i).value)
    UCSBnonResAd.append(sheet1.cell(row=47, column = i).value)
    UCSBnonResAp.append(sheet1.cell(row=48, column = i).value)
    UCSBapRatio.append(sheet1.cell(row=49, column = i).value)
    UCSBadRatio.append(sheet1.cell(row=50, column = i).value)
    
    UCSCresAd.append(sheet1.cell(row=52, column = i).value)
    UCSCresAp.append(sheet1.cell(row=53, column = i).value)
    UCSCnonResAd.append(sheet1.cell(row=54, column = i).value)
    UCSCnonResAp.append(sheet1.cell(row=55, column = i).value)
    UCSCapRatio.append(sheet1.cell(row=56, column = i).value)
    UCSCadRatio.append(sheet1.cell(row=57, column = i).value)
    
UCBresAd

# %%
plt.figure(figsize=(12, 10))
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)

plt.plot(UCyears, resAd, color = tableau[1], lw = 3)
plt.plot(UCyears, resAp, color = tableau[1], lw = 3)
#blue is residents
plt.plot(UCyears, nonResAd, color = tableau[2], lw = 3)#, linestyle = ':' )
plt.plot(UCyears, nonResAp, color = tableau[2], lw = 3)#, linestyle = ':' )
#orange is non-res
         
plt.plot(yearsG, resAdG, color = tableau[1], lw = 3, linestyle = ':' )
plt.plot(yearsG, resApG, color = tableau[1], lw = 3, linestyle = ':' )
#blue is residents
plt.plot(yearsG, nonResAdG, color = tableau[2], lw = 3, linestyle = ':' )
plt.plot(yearsG, nonResApG, color = tableau[2], lw = 3, linestyle = ':' )

plt.title("UCSD Resident vs Non-Resident Admissions", fontsize = 22)
plt.xlim(0, 8)
plt.xticks(range(0, 8, 1), ["201" + str(x) for x in range(1, 8, 1)], fontsize=14)  
plt.ylim(3000, 60000)
plt.text(6, 53000, 'Resident Applicants', color = tableau[1] )
plt.text(6, 24000, 'Non-Resident Applicants',  color = tableau[2])
plt.text(6, 16500, 'Resident Admits',  color = tableau[1])
plt.text(6, 10000, 'Non-Resident Admits',  color = tableau[2])
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Number of Students', fontsize = 14)
plt.text(4, -5000, "Data sources: http://www.ucop.edu/news/factsheets/2014/fall-2014-admissions-table2.pdf" 
       "\nhttp://www.ucop.edu/institutional-research-academic-planning/_files/factsheets/2015/fall-2015-admissions-table2.pdf"
       "\nAuthor: Ayat Amin "    
       "\nNote:  ", fontsize=10, ha="center") 
plt.show()

# %%
plt.figure(figsize=(12, 10))
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)
plt.xlim(1, 8)
plt.xticks(range(1, 8, 1), ["201" + str(x) for x in range(1, 8, 1)], fontsize=14)  
#plt.yticks(range(0, 5, 1), [str(x) + "%" for x in range(0, 5, 1)], fontsize=14)    
plt.ylim(0, 5)

ax.plot(yearsRatio, apRatio, color = tableau[2], lw = 3)
#origin is applied
ax.plot(yearsRatio, adRatio, color = tableau[1], lw = 3 )
ax.plot(yearsG, apRatioG, color = tableau[2], lw = 3, linestyle = ':' )
#origin is applied
ax.plot(yearsG, adRatioG, color = tableau[1], lw = 3, linestyle = ':' )

plt.title("Ratio Non-Residents vs Residents", fontsize = 22)
plt.text(6.1, 1.7, 'Applicant Ratio', color = tableau[1] )
plt.text(6.1, 2.25, 'Admit Ratio',  color = tableau[2])
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Ratio Resident/Non-Resident', fontsize = 14)
plt.text(4.5, .25, "Data sources: http://www.ucop.edu/news/factsheets/2014/fall-2014-admissions-table2.pdf" 
       "\nhttp://www.ucop.edu/institutional-research-academic-planning/_files/factsheets/2015/fall-2015-admissions-table2.pdf"
       "\nAuthor: Ayat Amin ", fontsize=10, ha="center") 
plt.show()

# %% [markdown]
# plt.figure(figsize=(12, 10))
# ax = plt.subplot(111)
# ax.spines["top"].set_visible(False)
# ax.spines["bottom"].set_visible(False)
# ax.spines["right"].set_visible(False)
# ax.spines["left"].set_visible(False)
#
# #UCSD is Blue
# #plt.plot(UCyears, resAd, color = tableau[1], lw = 3)
# #plt.plot(UCyears, resAp, color = tableau[1], lw = 3)
# #plt.plot(UCyears, nonResAd, color = tableau[2], lw = 3)
# #plt.plot(UCyears, nonResAp, color = tableau[2], lw = 3)
#
# #UCB is green
# plt.plot(years, UCBresAd, color = tableau[0], lw = 3)
# plt.plot(years, UCBresAp, color = tableau[0], lw = 3)
# plt.plot(years, UCBnonResAd, color = tableau[1], lw = 3)
# plt.plot(years, UCBnonResAp, color = tableau[1], lw = 3)
# plt.text(2015, 20000, 'UCB', color = tableau[0] )
#
# #UCD is red
# plt.plot(years, UCDresAd, color = tableau[3], lw = 3)
# plt.plot(years, UCDresAp, color = tableau[3], lw = 3)
# plt.plot(years, UCDnonResAd, color = tableau[4], lw = 3)
# plt.plot(years, UCDnonResAp, color = tableau[4], lw = 3)
# plt.text(2015, 25000, 'UCD', color = tableau[3] )
#
# #UCLA is orange
# plt.plot(years, UCLAresAd, color = tableau[5], lw = 3)
# plt.plot(years, UCLAresAp, color = tableau[5], lw = 3)
# plt.plot(years, UCLAnonResAd, color = tableau[6], lw = 3)
# plt.plot(years, UCLAnonResAp, color = tableau[6], lw = 3)
# plt.text(2015, 30000, 'UCLA', color = tableau[5] )
#
# #UCM is purple
# plt.plot(years, UCMresAd, color = tableau[7], lw = 3)
# plt.plot(years, UCMresAp, color = tableau[7], lw = 3)
# plt.plot(years, UCMnonResAd, color = tableau[8], lw = 3)
# plt.plot(years, UCMnonResAp, color = tableau[8], lw = 3)
# plt.text(2015, 35000, 'UCM', color = tableau[7] )
#
# #UCI is brown
# plt.plot(years, UCIresAd, color = tableau[9], lw = 3)
# plt.plot(years, UCIresAp, color = tableau[9], lw = 3)
# plt.plot(years, UCInonResAd, color = tableau[9], lw = 3)
# plt.plot(years, UCInonResAp, color = tableau[9], lw = 3)
# plt.text(2015, 40000, 'UCI', color = tableau[9] )
#
# #UCR is weird green
# plt.plot(years, UCRresAd, color = tableau[11], lw = 3)
# plt.plot(years, UCRresAp, color = tableau[11], lw = 3)
# plt.plot(years, UCRnonResAd, color = tableau[11], lw = 3)
# plt.plot(years, UCRnonResAp, color = tableau[11], lw = 3)
# plt.text(2015, 45000, 'UCR', color = tableau[11] )
#
# #UCSB is light blue
# plt.plot(years, UCSBresAd, color = tableau[13], lw = 3)
# plt.plot(years, UCSBresAp, color = tableau[13], lw = 3)
# plt.plot(years, UCSBnonResAd, color = tableau[13], lw = 3)
# plt.plot(years, UCSBnonResAp, color = tableau[13], lw = 3)
# plt.text(2015, 50000, 'UCSB', color = tableau[13] )
#
# #UCSD is grey
# plt.plot(years, UCSCresAd, color = tableau[15], lw = 3)
# plt.plot(years, UCSCresAp, color = tableau[15], lw = 3)
# plt.plot(years, UCSCnonResAd, color = tableau[15], lw = 3)
# plt.plot(years, UCSCnonResAp, color = tableau[15], lw = 3)
# plt.text(2015, 55000, 'UCSC', color = tableau[15] )
#
#
# plt.title("UCSD Resident vs Non-Resident Admissions", fontsize = 22)
# plt.xlim(2012, 2016)
# plt.ylim(3000, 60000)
# plt.xticks(range(2010, 2017, 1), fontsize=14)
# plt.xlabel('Year')
# plt.ylabel('Number of Students')
# plt.text(2014, -20, "Data sources: http://www.ucop.edu/news/factsheets/2014/fall-2014-admissions-table2.pdf"
#        "\nhttp://www.ucop.edu/institutional-research-academic-planning/_files/factsheets/2015/fall-2015-admissions-table2.pdf"
#        "\nAuthor: Ayat Amin "
#        "\nNote:  ", fontsize=12, ha="center")
# plt.show()
# plt.savefig("UCSD-res-non-res.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12, 10))
ax = plt.subplot(111)  
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)
plt.xlim(1, 8)
plt.xticks(range(1, 8, 1), ["201" + str(x) for x in range(1, 8, 1)], fontsize=14)  
#plt.yticks(range(0, 5, 1), [str(x) + "%" for x in range(0, 5, 1)], fontsize=14)    
plt.ylim(0, 2)

ax.plot(yearsRatio, diff, color = tableau[5], lw = 3)
ax.plot(yearsG, diffG, color = tableau[5], lw = 3, linestyle = ':' )

plt.title("Difference Between Admit and Applied Ratios", fontsize = 22)
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Admit Ratio - Applied Ratio', fontsize = 14)
plt.text(4.5, .05, "Data sources: http://www.ucop.edu/news/factsheets/2014/fall-2014-admissions-table2.pdf" 
       "\nhttp://www.ucop.edu/institutional-research-academic-planning/_files/factsheets/2015/fall-2015-admissions-table2.pdf"
       "\nAuthor: Ayat Amin ", fontsize=10, ha="center") 
plt.show()
